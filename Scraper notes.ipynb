# %%
from bs4 import BeautifulSoup as BS
import requests
import datetime
from datetime import date
from datetime import datetime
today = date.today()
print("Today's date:", today)
Now = datetime.now()

print("Today's date:", today)
# Out:
# Today's date: 2020-08-02
# Today's date: 2020-08-02

# %%
url = "https://www.libyaalahrar.tv/local/"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
}
response = requests.get(url, headers=headers)
soup = BS(response.text, 'html.parser')
results = soup.find_all(class_="site tie-container")
# for x in results:
#     print(x.text)
#     print(f'https://libyaalahrar.tv/{(x("a")[0]["href"])}')
#     print("*************")

for x in results:
    print(x)
# Out:
# <div class="site tie-container" id="tie-container"> <div id="tie-wrapper"> <header class="theme-header header-layout-1 main-nav-dark main-nav-below has-custom-sticky-logo mobile-header-default" id="theme-header"> <div class="main-nav-wrapper"> <nav aria-label="القائمة الرئيسية" class="main-nav header-nav" id="main-nav" style="line-height:96px"> <div class="container"> <div class="main-menu-wrapper"> <div class="header-layout-1-logo" style="width:219px"> <a href="#" id="mobile-menu-icon"> <span class="nav-icon"></span> <span class="screen-reader-text">القائمة</span> </a> <div class="image-logo" id="logo"> <a href="/" title="ليبيا الأحرار"> <img alt="ليبيا الأحرار" class="logo_normal" height="56" src="https://1osxmfhwk437nzd724qu2fvt-wpengine.netdna-ssl.com/wp-content/uploads/2020/07/Libya-AlAhrar-Logo.png" style="max-height:56px; width: auto;" width="219"/> <img alt="ليبيا الأحرار" class="logo_2x" height="56" src="https://1osxmfhwk437nzd724qu2fvt-wpengine.netdna-ssl.com/wp-content/uploads/2020/07/Libya-AlAhrar-Logo.png" style="max-height:56px; width: auto;" width="219"/> <h1 class="h1-off">ليبيا</h1> </a> </div> </div> <div id="menu-components-wrap"> <div class="image-logo" id="sticky-logo"> <a href="/" title="ليبيا الأحرار"> <img alt="ليبيا الأحرار" class="logo_normal" src="https://1osxmfhwk437nzd724qu2fvt-wpengine.netdna-ssl.com/wp-content/uploads/2020/07/Libya-AlAhrar-Logo.png" style="max-height:49px; width: auto;"/> <img alt="ليبيا الأحرار" class="logo_2x" src="https://1osxmfhwk437nzd724qu2fvt-wpengine.netdna-ssl.com/wp-content/uploads/2020/07/Libya-AlAhrar-Logo.png" style="max-height:49px; width: auto;"/> </a> </div> <div class="flex-placeholder"></div> <div class="main-menu main-menu-wrap tie-alignleft"> <div class="main-menu header-menu" id="main-nav-menu"><ul class="menu" id="menu-main-menu" role="menubar"><li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-1317 current_page_item menu-item-4425 tie-current-menu" id="menu-item-4425"><a href="./">ليبيا</a></li> <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4431" id="menu-item-4431"><a href="/economy/">اقتصاد</a></li> <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4426" id="menu-item-4426"><a href="/sports/">رياضة</a></li> <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4429" id="menu-item-4429"><a href="/services/">خدمات</a></li> <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4680" id="menu-item-4680"><a href="/%d9%85%d9%86%d9%88%d8%b9%d8%a7%d8%aa/">منوعات</a></li> <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-15350" id="menu-item-15350"><a href="/category/reads/">تقارير</a></li> <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-64975" id="menu-item-64975"><a href="/category/opinion/">رأي</a></li> <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-68251" id="menu-item-68251"><a href="//www.youtube.com/c/LibyaAlAhrartv/videos" target="_blank">فيديو</a></li> <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-58829" id="menu-item-58829"><a href="/live/">البث المباشر</a></li> </ul></div> </div> <ul class="components"> <li class="search-compact-icon menu-item custom-menu-link"> <a class="tie-search-trigger" data-type="modal-trigger" href="#"> <span aria-hidden="true" class="fa fa-search"></span> <span class="screen-reader-text">بحث عن</span> </a> <span class="cd-modal-bg"></span> </li> </ul> </div> </div> </div> </nav> </div> </header> <div class="section-wrapper container-full without-background" id="tiepost-1055-section-3806"> <div class="section-item is-first-section full-width"> <div class="container"> <div class="tie-row main-content-row"> <div class="main-content tie-col-md-12"> <section class="slider-area mag-box" id="tie-block_1904"> <div class="tie-main-slider main-slider boxe ...

# %%
# AlAhrar
LibyaAhrar=[]
Retrieved= Now

try:
    url = "https://www.libyaalahrar.tv/local/"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
    }
    response = requests.get(url, headers=headers)
    soup = BS(response.text, 'html.parser')
    results = soup.find_all(class_="post-title")

    for x in results:
        Headline = (x.text)
        Link = f'https://libyaalahrar.tv/{(x("a")[0]["href"])}'
        Headlines = {"Headline": Headline, "Link": Link}
        LibyaAhrar.append(Headlines)

    LibyaAhrar.append(Retrieved)
except:
    print("Error with AlAhrar")
else:
    print("Successfully completed")
# Out:
# Successfully completed

# %%
LibyaAhrar[0]["Headline"]
# Out:
# 'دراه: رصدنا رحلات جوية لطيران عسكري روسي في ليبيا'
